# %% [markdown]
# # Arrays

# %%
import numpy as np

# %%
a = np.array([[0,1,2,3], [4,5,6,7]])
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
a.shape
# Out:
# (2, 4)

# %%
a[1,3]
# Out:
# 7

# %%
a[1,2] = 8
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 8, 7]])

# %%
a[0]
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# # Generating Random Numbers

# %%
import random

# %%
prob = random.random()
print(prob)
# Out:
# 0.44014269047414767

# %%
number = random.randint(1,6)
print(number)
# Out:
# 2

# %%
import numpy as np

# %%
np.random.randint(1,6,(4,6))
# Out:
# array([[3, 3, 1, 4, 4, 2],
#        [3, 4, 3, 5, 4, 4],
#        [2, 2, 1, 2, 5, 3],
#        [3, 1, 4, 1, 3, 5]])

# %% [markdown]
# # Importing and Organizing Data in Python

# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.142970
# 1    0.654607
# 2    0.557805
# 3    0.286759
# 4    0.484800
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.5578046932629416

# %%
from pandas_datareader import data as wb

# %%
PG = wb.DataReader('PG', data_source='yahoo', start = '1995-1-1')

# %%
PG
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750   3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750   2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000   2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250   3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750   1795200.0
# ...                ...         ...         ...         ...         ...
# 2021-09-17  146.279999  144.229996  144.369995  144.339996  18737400.0
# 2021-09-20  144.850006  141.970001  144.220001  142.889999  10238700.0
# 2021-09-21  144.529999  142.880005  142.979996  143.110001   6651300.0
# 2021-09-22  144.350006  142.860001  143.820007  143.600006   6332500.0
# 2021-09-23  144.684998  143.490005  144.059998  144.190002   5151412.0
#
#              Adj Close
# Date
# 1995-01-03    8.063840
# 1995-01-04    7.999201
# 1995-01-05    7.886079
# ...

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6730 entries, 1995-01-03 to 2021-09-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       6730 non-null   float64
#  1   Low        6730 non-null   float64
#  2   Open       6730 non-null   float64
#  3   Close      6730 non-null   float64
#  4   Volume     6730 non-null   float64
#  5   Adj Close  6730 non-null   float64
# dtypes: float64(6)
# memory usage: 368.0 KB

# %%
PG.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.063840
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   7.999201
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.886079
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.902242
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.869921

# %%
PG.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-17  146.279999  144.229996  144.369995  144.339996  18737400.0
# 2021-09-20  144.850006  141.970001  144.220001  142.889999  10238700.0
# 2021-09-21  144.529999  142.880005  142.979996  143.110001   6651300.0
# 2021-09-22  144.350006  142.860001  143.820007  143.600006   6332500.0
# 2021-09-23  144.684998  143.490005  144.059998  144.190002   5151412.0
#
#              Adj Close
# Date
# 2021-09-17  144.339996
# 2021-09-20  142.889999
# 2021-09-21  143.110001
# 2021-09-22  143.600006
# 2021-09-23  144.190002

# %%
tickers = ['PG', 'MSFT', 'T', 'F', 'GE']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T      F          GE
# Date
# 2021-09-17  144.339996  299.869995  27.530001  13.55  100.470001
# 2021-09-20  142.889999  294.299988  27.209999  12.82   99.809998
# 2021-09-21  143.110001  294.799988  26.959999  12.77   96.820000
# 2021-09-22  143.600006  298.579987  27.010000  13.23   98.540001
# 2021-09-23  144.190002  299.559998  27.190001  13.71  102.959999

# %%
import quandl

# %%
mydata_01 = quandl.get("FRED/GDP")

# %%
mydata_01.tail()
# Out:
#                 Value
# Date
# 2020-04-01  19477.444
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22731.369

# %%
mydata_01.head()
# Out:
#               Value
# Date
# 1947-01-01  243.164
# 1947-04-01  245.968
# 1947-07-01  249.585
# 1947-10-01  259.745
# 1948-01-01  265.742

# %%
import pandas as pd

# %%
mydata_01.to_csv('C:/Users/Jared/Documents/GitHub/python_for_finance/example_01.csv')
